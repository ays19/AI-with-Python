# %% [markdown]
# # Calculating Mean

# %% [markdown]
# # Method 1 - Manual Calculation

# %%
# Population data
population_data = [150,160,170,180,145]

# Sample data
sample_data = [150,170,165]

# Calculate population mean
population_mean = sum(population_data)/ len(population_data)
print(f"Population Mean: {population_mean}")

# Calculate sample mean
sample_mean = sum(sample_data)/ len(sample_data)
print(f"Sample Mean: {sample_mean}")
# Out:
# Population Mean: 161.0
# Sample Mean: 161.66666666666666

# %% [markdown]
# # Method 2 - Using Numpy

# %%
import numpy as np
# define the dataset
data = [80,90,20,70,30]

#calculate the mean using numpy
arithmetic_mean = np.mean(data)

# Output the result
print(f"Arithmentic Mean using numpy: {arithmetic_mean}")
# Out:
# Arithmentic Mean using numpy: 58.0

# %% [markdown]
# # Method 3 - Using Staistics

# %%
import statistics as stats

# sample dataset
data = [10,50,55,78,89]

#Calculate the mean using statistics module
mean_stats = stats.mean(data)

print(f"Mean using statistics module: {mean_stats}")
# Out:
# Mean using statistics module: 56.4

# %% [markdown]
# # Finding mean - Data set

# %%
import seaborn as sns
import numpy as np

# Load the iris dataset
iris = sns.load_dataset("iris")

#Display the first few rows of the dataset
print(iris.head())

# Calculate the mean of the ;sepal_length' column
mean_sepal_length = np.mean(iris['sepal_length'])

# Output the result
print(f"The mean of the 'sepal_length' column is: {mean_sepal_length}")
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# The mean of the 'sepal_length' column is: 5.843333333333334

# %% [markdown]
# # Calculating pandas

# %% [markdown]
# # Method 1 - Using Numpy

# %%
import numpy as np

#Smaple dataset
data =  [20,22,28,30,32]

#Calculating the median using numpy
median_np = np.median(data)

print(f"Median using numpy: {median_np}")
# Out:
# Median using numpy: 28.0

# %% [markdown]
# # Method 2 - Using Statistics module

# %%
import statistics as stats

# Sample daraset
data =  [20,22,28,30,32,100]

#Calculating the median using Statistics module
median_stats = stats.median(data)

print(f"Median using stattistics module: {median_stats}")
# Out:
# Median using stattistics module: 29.0

# %% [markdown]
# # Method 3 - Using Pandas

# %%
import pandas as pd

# Create a simple Dataframe
df = pd.DataFrame({
    'values': [12,23,34,45,56,67]
})

# Calculate the median using pandas
median_pandas = df['values'].median()

print(f"Median using pandas: {median_pandas}")
# Out:
# Median using pandas: 39.5
