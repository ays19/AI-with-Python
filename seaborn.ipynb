# %% [markdown]
# # Seaborn Library

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/ays19/anaconda3/lib/python3.14/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/ays19/anaconda3/lib/python3.14/site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in /home/ays19/anaconda3/lib/python3.14/site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/ays19/anaconda3/lib/python3.14/site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ays19/anaconda3/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/ays19/anaconda3/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ays19/anaconda3/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ays19/anaconda3/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/ays19/anaconda3/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=9 in /home/ays19/anaconda3/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/ays19/anaconda3/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ays19/anaconda3/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/ays19/anaconda3/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
var1 = [1,2,3,4,5,6,7,8]
var2 = [8,7,6,5,4,3,2,1]

# %%
sns.lineplot(x=var1,y=var2)
plt.show()

# %%
df1 = sns.load_dataset("penguins")

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.lineplot(x= 'bill_length_mm', y='flipper_length_mm', data=df1)
plt.show()

# %%
sns.lineplot(x ='bill_length_mm', y='flipper_length_mm', data = df1, hue='sex')
plt.show()

# %%
sns.lineplot(x ='bill_length_mm', y='flipper_length_mm', data = df1, hue='sex',
            style ='sex', palette = "rocket_r", markers = ["o", ">"])
plt.show()

# %%
df1.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
import pandas as pd

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
df1['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 344, dtype: str

# %%
sns.barplot(x=df1.island, y=df1.bill_length_mm)
plt.show()

# %%
sns.barplot(x="island", y="bill_length_mm", data = df1, hue ="sex")
plt.show()

# %%
sns.barplot(x="island", y="bill_length_mm", data = df1, hue ="sex", palette = 'prism')
plt.show()

# %%
sns.barplot(x="island", y="bill_length_mm", data = df1, hue ="sex", palette = 'gist_heat')
plt.show()

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.displot(df1['flipper_length_mm'])
plt.show()

# %%
sns.displot(df1['flipper_length_mm'], bins = [170,180,190,200,210,220,230,240])
plt.show()

# %%
sns.displot(df1['flipper_length_mm'], bins = [170,180,190,200,210,220,230,240],
           color = "green")
plt.show()

# %%
sns.displot(df1['flipper_length_mm'], bins = [170,180,190,200,210,220,230,240],
           color = "red", kde = True)
plt.show()

# %%
pip install SpeechRecognition pyttsx3 wikipedia
# Out:
# Collecting SpeechRecognition
#   Downloading speechrecognition-3.17.0-py3-none-any.whl.metadata (28 kB)
# Collecting pyttsx3
#   Downloading pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions in /home/ays19/anaconda3/lib/python3.14/site-packages (from SpeechRecognition) (4.16.0)
# Collecting standard-aifc (from SpeechRecognition)
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting audioop-lts (from SpeechRecognition)
#   Downloading audioop_lts-0.2.2-cp313-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /home/ays19/anaconda3/lib/python3.14/site-packages (from wikipedia) (4.15.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/ays19/anaconda3/lib/python3.14/site-packages (from wikipedia) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ays19/anaconda3/lib/python3.14/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/ays19/anaconda3/lib/python3.14/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/ays19/anaconda3/lib/python3.14/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/ays19/anaconda3/lib/python3.14/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2026.6.17)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/ays19/anaconda3/lib/python3.14/site-packages (from beautifulsoup4->wikipedia) (2.8.4)
# Collecting standard-chunk (from standard-aifc->SpeechRecognition)
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Downloading speechrecognition-3.17.0-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 431.6 kB/s  0:01:24 eta 0:00:010:00:02
# Downloading pyttsx3-2.99-py3-none-any.whl (32 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (85 kB)
# Downloading standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Downloading standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (pyproject.toml) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11757 sha256=641af3c0c1b57d2da7f7e985669cfd8b628e41e8208407df1a0574b43864dd13
#   Stored in directory: /home/ays19/.cache/pip/wheels/30/24/d3/9d46daa49494cef2f32dc9a8f203aac1f10cec980adba03d1f
# Successfully built wikipedia
# Installing collected packages: standard-chunk, pyttsx3, audioop-lts, wikipedia, standard-aifc, SpeechRecognition
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [SpeechRecognition]32m5/6 [SpeechRecognition]fc]
# Successfully installed SpeechRecognition-3.17.0 audioop-lts-0.2.2 pyttsx3-2.99 standard-aifc-3.13.0 standard-chunk-3.13.0 wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio
# Out:
# Collecting pyaudio
#   Downloading PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [26 lines of output]
#       /tmp/pip-build-env-7nudlw_j/overlay/lib/python3.14/site-packages/setuptools/dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-314/pyaudio
#       copying src/pyaudio/__init__.py -> build/lib.linux-x86_64-cpython-314/pyaudio
#       running build_ext
#       building 'pyaudio._portaudio' extension
#       gcc -pthread -B /home/ays19/anaconda3/compiler_compat -fno-strict-overflow -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/ays19/anaconda3/include -fPIC -O2 -isystem /home/ays19/anaconda3/include -fPIC -I/usr/local/include -I/usr/include -I/home/ays19/anaconda3/include/python3.14 -c src/pyaudio/device_api.c -o build/temp.linux-x86_64-cpython-314/src/pyaudio/device_api.o
#       src/pyaudio/device_api.c:9:10: fatal error: portaudio.h: No such file or directory
#           9 | #include "portaudio.h"
#             |          ^~~~~~~~~~~~~
#       compilation terminated.
#       error: Command '['gcc', '-pthread', '-B', '/home/ays19/anaconda3/compiler_compat', '-fno-strict-overflow', '-Wsign-compare', '-DNDEBUG', '-O2', '-Wall', '-fPIC', '-O2', '-isystem', '/home/ays19/anaconda3/include', '-fPIC', '-O2', '-isystem', '/home/ays19/anaconda3/include', '-fPIC', '-I/usr/local/include', '-I/usr/include', '-I/home/ays19/anaconda3/include/python3.14', '-c', 'src/pyaudio/device_api.c', '-o', 'build/temp.linux-x86_64-cpython-314/src/pyaudio/device_api.o']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> pyaudio
# Note: you may need to restart the kernel to use updated packages.
