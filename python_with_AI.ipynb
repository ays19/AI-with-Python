# %% [markdown]
# # Unit-1: Fundamentals of Python

# %%
import sys
sys.version
# Out:
# '3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:37:38) [GCC 14.3.0]'

# %% [markdown]
# # Python Comments

# %%
# this step for print
print("Programming")
# Out:
# Programming

# %% [markdown]
# # Multiple Comment

# %%
"""
Steps of program:
1. Take number
2. square the number
3. Print result
"""

num = 9
square = num * num
print(square)
# Out:
# 81

# %% [markdown]
# # Unit 2
