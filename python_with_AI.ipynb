# %% [markdown]
# # Unit-1: Fundamentals of Python

# %%
import sys
sys.version
# Out:
# '3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:37:38) [GCC 14.3.0]'

# %% [markdown]
# # Python Comments

# %%
# this step for print
print("Programming")
# Out:
# Programming

# %% [markdown]
# # Multiple Comment

# %%
"""
Steps of program:
1. Take number
2. square the number
3. Print result
"""

num = 9
square = num * num
print(square)
# Out:
# 81

# %% [markdown]
# # Unit 2

# %%
_abc = "Ahsan"
print(_abc)
# Out:
# Ahsan

# %%
x = 4
print(x)
print(type(x))
# Out:
# 4
# <class 'int'>

# %%
y = 4.5
print(y)
print(type(y))
# Out:
# 4.5
# <class 'float'>

# %%
z = "Sharar"
print(z)
print(type(z))
# Out:
# Sharar
# <class 'str'>

# %%
u = 1+2j
print(u)
print(type(u))
# Out:
# (1+2j)
# <class 'complex'>
