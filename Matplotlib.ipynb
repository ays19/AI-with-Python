# %% [markdown]
# # Matplotlib  (Visualization with Python)

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [5,6,7,8]

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4]
y = [5,6,7,8]
c = 'r'

plt.plot(x,y,c)
plt.show()

# %%
x = [5,7,19,5,8,9]
y = [10,6,8,2,19,24]

plt.plot(x,y)
plt.show()

# %%
x = [5,2,9,4,7]

y = [10,5,8,4,2]

plt.plot(x,y)
plt.plot(y, marker = 'o')

plt.show()
